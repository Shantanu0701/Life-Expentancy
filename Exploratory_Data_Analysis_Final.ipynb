# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
import numpy as np

# %%
parentDir = "D:/CDAC/IACSD/Project/"
pd.set_option('display.float_format', lambda x: '%.3f' % x)
life_exep_data = pd.read_csv(parentDir + 'life_expectancy/imp/final.csv')

# %%
life_exep_data.head()
# Out:
#        Country  Year  Gender  Life expectancy  Unemployment  Infant Mortality  \
# 0  Afghanistan  2000  Female           57.120        13.846            85.000
# 1  Afghanistan  2001  Female           57.596        13.849            82.700
# 2  Afghanistan  2002  Female           58.080        14.355            80.400
# 3  Afghanistan  2003  Female           58.578        14.222            77.800
# 4  Afghanistan  2004  Female           59.093        14.047            75.300
#
#               GDP             GNI  Clean fuels and cooking technologies  \
# 0 13684491660.790 18240442244.769                                 6.400
# 1 13684491660.790 18240442244.769                                 7.200
# 2  4055179566.350 18240442244.769                                 8.200
# 3  4515558808.110 18240442244.769                                 9.400
# 4  5226778808.892 18240442244.769                                10.400
#
#    Per Capita  ...  DPT Immunization  HepB3 Immunization  \
# 0     434.740  ...            24.000              65.077
# 1     434.740  ...            33.000              65.077
# 2     179.427  ...            36.000              65.077
# 3     190.684  ...            41.000              65.077
# 4     211.382  ...            50.000              65.077
#
#    Measles Immunization  Hospital beds  Basic sanitation services  \
# 0                27.000          0.300                     21.871
# 1                37.000          0.390                     21.881
# 2                35.000          0.390                     23.274
# 3                39.000          0.390                     24.667
# 4                48.000          0.390                     26.068
#
#    Tuberculosis treatment  Urban population  Rural population  \
# 0                  85.000            22.078            77.922
# 1                  84.000            22.169            77.831
# 2                  87.000            22.261            77.739
# 3                  86.000            22.353            77.647
# 4                  89.000            22.500            77.500
#
#    Non-communicable Mortality  Sucide Rate
# 0                      39.400        4.800
# 1                      40.100        4.800
# 2                      40.500        4.600
# 3                      40.100        4.600
# 4                      40.200        4.600
#
# [5 rows x 22 columns]

# %%
life_exep_data.describe()
# Out:
#           Year  Life expectancy  Unemployment  Infant Mortality  \
# count 9928.000         9928.000      9928.000          9928.000
# mean  2009.495           69.834         8.256            30.235
# std      5.762            9.302         6.155            25.461
# min   2000.000           38.861         0.052             1.400
# 25%   2005.000           63.894         4.331             9.300
# 50%   2009.000           71.445         6.561            23.300
# 75%   2014.000           76.845        10.133            44.865
# max   2019.000           88.100        43.166           146.200
#
#                      GDP                GNI  \
# count           9928.000           9928.000
# mean   2032870320199.638  2042053577025.779
# std    7249369673698.859  7254721460142.498
# min         63101272.370       72802185.001
# 25%       7267552276.129     7584112233.046
# 50%      45247974037.038    45940355554.258
# 75%     501278724553.924   523061711019.377
# max   87568054407493.094 87532722519257.594
#
#        Clean fuels and cooking technologies  Per Capita  \
# count                              9928.000    9928.000
# mean                                 60.593   12668.853
# std                                  36.964   19447.598
# min                                   0.000     111.927
# 25%                                  23.000    1366.059
# 50%                                  61.950    4348.605
# 75%                                  99.334   14443.944
# max                                 100.000  180366.715
#
#        Mortality caused by road traffic injury  Tuberculosis Incidence  \
# count                                 9928.000                9928.000
# mean                                    18.229                 136.043
# std                                      8.223                 176.090
# min                                      0.000                   0.000
# 25%                                     12.700                  21.000
# 50%                                     18.229                  82.000
# 75%                                     24.100                 159.000
# max                                     64.600                1590.000
#
#        DPT Immunization  HepB3 Immunization  Measles Immunization  \
# count          9928.000            9928.000              9928.000
# mean             85.685              81.308                84.855
# std              14.208              18.469                14.218
# min              19.000               0.050                16.000
# 25%              81.000              75.083                79.000
# 50%              90.104              86.700                89.320
# 75%              96.000              95.000                95.092
# max              99.000              99.000                99.000
#
#        Hospital beds  Basic sanitation services  Tuberculosis treatment  \
# count       9928.000                   9928.000                9928.000
# mean           2.986                     71.106                  76.726
# std            2.284                     29.583                  14.757
# min            0.010                      2.755                   0.000
# 25%            1.308                     46.007                  73.000
# 50%            2.632                     84.227                  78.000
# 75%            3.600                     97.177                  86.000
# max           14.690                    100.000                 100.000
#
#        Urban population  Rural population  Non-communicable Mortality  \
# count          9928.000          9928.000                    9928.000
# mean             55.559            44.441                      22.100
# std              22.436            22.436                       8.504
# min               8.246             0.000                       4.400
# 25%              36.519            26.118                      16.300
# 50%              55.367            44.633                      21.925
# 75%              73.882            63.481                      26.200
# max             100.000            91.754                      64.100
#
#        Sucide Rate
# count     9928.000
# mean        10.619
# std         11.070
# min          0.000
# 25%          4.000
# 50%          7.800
# 75%         12.300
# max        147.800

# %%
life_exep_data.skew(axis = 0, numeric_only = True)
# Out:
# Year                                      -0.001
# Life expectancy                           -0.617
# Unemployment                               1.768
# Infant Mortality                           1.089
# GDP                                        5.889
# GNI                                        5.910
# Clean fuels and cooking technologies      -0.383
# Per Capita                                 2.994
# Mortality caused by road traffic injury    0.213
# Tuberculosis Incidence                     3.097
# DPT Immunization                          -1.661
# HepB3 Immunization                        -1.792
# Measles Immunization                      -1.434
# Hospital beds                              1.668
# Basic sanitation services                 -0.759
# Tuberculosis treatment                    -2.230
# Urban population                           0.067
# Rural population                          -0.067
# Non-communicable Mortality                 0.880
# Sucide Rate                                3.686
# dtype: float64

# %%
## Inter Quartile Range(IQR)
## Equation -> IQR = Q3 - Q1
## min value of whiskers in box plot -> Q1 - 1.5 * IQR
## max value of whiskers in box plot -> Q3 + 1.5 * IQR

def min_max_iqr(df, column):
    Q1, Q3 = df[column].quantile([0.25, 0.75])
    IQR = Q3 - Q1
    min_valid = Q1 - 1.5 * IQR
    max_valid = Q3 + 1.5 * IQR
    return min_valid, max_valid

# %%
skip_columns = ['Country', 'Year', 'Gender']
for column in life_exep_data.columns:
    if not column in skip_columns:
        min_valid, max_valid = min_max_iqr(life_exep_data, column)
        outlier_rows = life_exep_data[(life_exep_data[column] < min_valid) | (life_exep_data[column] > max_valid)]
        perc_outlier_rows = (outlier_rows.shape[0] / life_exep_data.shape[0])
        print("Column Name = ", column)
        print("min_valid = ", min_valid)
        print("max_valid = ", max_valid)
        print("Count of outlier rows = ", outlier_rows.shape[0])
        print("% of outlier rows = ", perc_outlier_rows, end = '\n')
        print(end = '\n')
# Out:
# Column Name =  Life expectancy
# min_valid =  44.46775000000001
# max_valid =  96.27174999999998
# Count of outlier rows =  59
# % of outlier rows =  0.005942788074133763
#
# Column Name =  Unemployment
# min_valid =  -4.37162542343135
# max_valid =  18.83537530899041
# Count of outlier rows =  758
# % of outlier rows =  0.07634971796937953
#
# Column Name =  Infant Mortality
# min_valid =  -44.04757453901824
# max_valid =  98.21262423169706
# Count of outlier rows =  153
# % of outlier rows =  0.015410958904109588
#
# Column Name =  GDP
# min_valid =  -733749206140.5651
# max_valid =  1242295482970.6182
# Count of outlier rows =  1780
# % of outlier rows =  0.17929089443996776
#
# Column Name =  GNI
# min_valid =  -765632285946.4509
# max_valid =  1296278109198.8738
# Count of outlier rows =  1814
# % of outlier rows =  0.18271555197421435
#
# Column Name =  Clean fuels and cooking technologies
# min_valid =  -91.50038376556871
# max_valid =  213.83397294261454
# Count of outlier rows =  0
# % of outlier rows =  0.0
#
# Column Name =  Per Capita
# min_valid =  -18250.767714121714
# max_valid =  34060.77132428995
# Count of outlier rows =  1240
# % of outlier rows =  0.12489927477840451
#
# Column Name =  Mortality caused by road traffic injury
# min_valid =  -4.400000000000002
# max_valid =  41.2
# Count of outlier rows =  14
# % of outlier rows =  0.0014101531023368251
#
# Column Name =  Tuberculosis Incidence
# min_valid =  -186.0
# max_valid =  366.0
# Count of outlier rows =  810
# % of outlier rows =  0.08158742949234489
#
# Column Name =  DPT Immunization
# min_valid =  58.5
# max_valid =  118.5
# Count of outlier rows =  648
# % of outlier rows =  0.0652699435938759
#
# Column Name =  HepB3 Immunization
# min_valid =  45.206693698395064
# max_valid =  124.87598378096297
# Count of outlier rows =  650
# % of outlier rows =  0.06547139403706688
#
# Column Name =  Measles Immunization
# min_valid =  54.861567148967694
# max_valid =  119.23072141838718
# Count of outlier rows =  488
# % of outlier rows =  0.04915390813859791
#
# Column Name =  Hospital beds
# min_valid =  -2.129513888888889
# max_valid =  7.037708333333333
# Count of outlier rows =  608
# % of outlier rows =  0.06124093473005641
#
# Column Name =  Basic sanitation services
# min_valid =  -30.7474448740505
# max_valid =  173.93173440366743
# Count of outlier rows =  0
# % of outlier rows =  0.0
#
# Column Name =  Tuberculosis treatment
# min_valid =  53.5
# max_valid =  105.5
# Count of outlier rows =  636
# % of outlier rows =  0.06406124093473006
#
# Column Name =  Urban population
# min_valid =  -19.52632983427771
# max_valid =  129.9265497237962
# Count of outlier rows =  0
# % of outlier rows =  0.0
#
# Column Name =  Rural population
# min_valid =  -29.92654972379619
# max_valid =  119.5263298342777
# Count of outlier rows =  0
# % of outlier rows =  0.0
#
# Column Name =  Non-communicable Mortality
# min_valid =  1.4500000000000028
# max_valid =  41.05
# Count of outlier rows =  319
# % of outlier rows =  0.03213134568896051
#
# Column Name =  Sucide Rate
# min_valid =  -8.450000000000001
# max_valid =  24.75
# Count of outlier rows =  752
# % of outlier rows =  0.0757453666398066

# %%
def plot_histogram(data, ylabel, xlabel, title):
    plt.figure(figsize = (10, 6))
    plt.hist(data, color = 'purple', edgecolor = "white")
    plt.ylabel(ylabel)
    plt.xlabel(xlabel)
    plt.title(title)
    plt.savefig(parentDir + "life_expectancy/images/histogram/" + title +'.png', transparent=False, facecolor='w')

# %%
def plot_boxplot(column):
    sns.boxplot(data = life_exep_data, x = life_exep_data[column], color = '#00A000')
    plt.savefig(parentDir + "life_expectancy/images/boxplot/" + column +'.png', transparent=False, facecolor='w')

# %%
def get_outlier(df, column):
    Q1, Q3 = df[column].quantile([0.25,0.75])
    IQR = Q3 - Q1
    return df[(df[column] > (Q3 + 1.5 * IQR)) | (df[column] < (Q1 - 1.5 * IQR))].sort_values(by = [column]).reset_index()

# %%
## Imputation of outlier (IQR)
# def impute_outliers(column):
#     min_valid, max_valid = min_max_iqr(life_exep_data, column)
#     # impute the outlier row values
#     life_exep_data.loc[ life_exep_data[column] < min_valid , column] = min_valid
#     life_exep_data.loc[ life_exep_data[column] > max_valid , column] = max_valid

# %% [markdown]
# Lets visualise the distribution of Life Expectancy at birth.

# %%
plot_histogram(life_exep_data['Life expectancy'], 'Count', 'Life Expectancy at Birth', 
               "Histogram of Life Expectancy at Birth")

# %% [markdown]
# From the above histogram we can conclude that most of data lies between 70 and 80.

# %%
# sns.boxplot(data=life_exep_data, x=life_exep_data['Life expectancy'], color='green')
plot_boxplot('Life expectancy')

# %%
df = get_outlier(life_exep_data, 'Life expectancy')

df[['Country','Year','Gender','Life expectancy']]
# Out:
#                      Country  Year  Gender  Life expectancy
# 0               Sierra Leone  2000    Male           38.861
# 1               Sierra Leone  2001    Male           39.745
# 2               Sierra Leone  2000  Female           40.005
# 3                    Lesotho  2006    Male           40.418
# 4                    Lesotho  2007    Male           40.555
# 5                    Lesotho  2005    Male           40.566
# 6                   Eswatini  2005    Male           40.663
# 7               Sierra Leone  2002    Male           40.708
# 8                   Eswatini  2004    Male           40.749
# 9                   Eswatini  2006    Male           40.923
# 10                   Lesotho  2008    Male           40.950
# 11              Sierra Leone  2001  Female           40.976
# 12                   Lesotho  2004    Male           41.012
# 13                  Eswatini  2003    Male           41.189
# 14                  Zimbabwe  2004    Male           41.366
# 15                  Zimbabwe  2003    Male           41.442
# 16                  Eswatini  2007    Male           41.473
# 17                  Zimbabwe  2005    Male           41.573
# 18                   Lesotho  2009    Male           41.579
# 19                  Zimbabwe  2002    Male           41.695
# 20              Sierra Leone  2003    Male           41.712
# 21                   Lesotho  2003    Male           41.717
# 22                    Zambia  2000    Male           41.927
# 23                  Eswatini  2002    Male           41.972
# 24              Sierra Leone  2002  Female           42.023
# 25                  Zimbabwe  2001    Male           42.086
# 26                  Zimbabwe  2006    Male           42.193
# 27                  Eswatini  2008    Male           42.255
# 28                   Lesotho  2010    Male           42.412
# 29                    Zambia  2001    Male           42.542
# 30                  Zimbabwe  2000    Male           42.609
# 31                   Lesotho  2002    Male           42.631
# 32  Central African Republic  2001    Male           42.704
# 33              Sierra Leone  2004    Male           42.726
# 34  Central African Republic  2000    Male           42.727
# 35  Central African Republic  2002    Male           42.787
# 36                    Malawi  2000    Male           42.836
# 37  Central African Republic  2003    Male           42.953
# 38                    Malawi  2001    Male           42.973
# 39                  Eswatini  2001    Male           43.078
# 40              Sierra Leone  2003  Female           43.103
# 41  Central African Republic  2004    Male           43.193
# 42                  Eswatini  2009    Male           43.227
# 43                  Zimbabwe  2007    Male           43.276
# 44                    Malawi  2002    Male           43.289
# 45                    Uganda  2000    Male           43.323
# 46                    Zambia  2002    Male           43.331
# 47                   Lesotho  2011    Male           43.417
# 48  Central African Republic  2005    Male           43.500
# 49                   Lesotho  2001    Male           43.712
# 50              Sierra Leone  2005    Male           43.731
# 51                    Malawi  2003    Male           43.807
# 52  Central African Republic  2006    Male           43.868
# 53              Sierra Leone  2004  Female           44.184
# 54                    Zambia  2003    Male           44.249
# 55  Central African Republic  2007    Male           44.291
# 56                  Eswatini  2010    Male           44.369
# 57                    Uganda  2001    Male           44.424
# 58                    Angola  2000    Male           44.466

# %% [markdown]
# Next we are going to do visualise the distribution of Unemployment column.

# %%
plot_histogram(life_exep_data['Unemployment'], 'Count', 'Unemployment', "Histogram of Unemployment")

# %% [markdown]
# From the above histogram we can conclude most of the data are between 5 to 10.

# %%
plot_boxplot('Unemployment')

# %%
df = get_outlier(life_exep_data, 'Unemployment')

df[['Country','Year','Gender','Unemployment']]
# Out:
#                     Country  Year  Gender  Unemployment
# 0                  Bulgaria  2001  Female        18.855
# 1    Bosnia and Herzegovina  2017    Male        18.857
# 2                    Poland  2003    Male        18.898
# 3                 St. Lucia  2015    Male        18.905
# 4               Congo, Rep.  2012    Male        18.911
# ..                      ...   ...     ...           ...
# 753            South Africa  2002  Female        41.372
# 754      West Bank and Gaza  2018  Female        41.873
# 755                 Lesotho  2001  Female        41.936
# 756      West Bank and Gaza  2017  Female        42.811
# 757                 Lesotho  2000  Female        43.166
#
# [758 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of Infant Mortality column.

# %%
plot_histogram(life_exep_data['Infant Mortality'], 'Count', 'Infant Mortality', "Histogram of Infant Mortality")

# %%
plot_boxplot('Infant Mortality')

# %%
df = get_outlier(life_exep_data, 'Infant Mortality')

df[['Country','Year','Gender','Infant Mortality']]
# Out:
#                                         Country  Year  Gender  \
# 0                                       Liberia  2005    Male
# 1                                          Chad  2006    Male
# 2                             Equatorial Guinea  2000  Female
# 3     Sub-Saharan Africa (IDA & IBRD countries)  2000    Male
# 4    Sub-Saharan Africa (excluding high income)  2000    Male
# ..                                          ...   ...     ...
# 148                                Sierra Leone  2003    Male
# 149                                     Liberia  2000    Male
# 150                                Sierra Leone  2002    Male
# 151                                Sierra Leone  2001    Male
# 152                                Sierra Leone  2000    Male
#
#      Infant Mortality
# 0              98.500
# 1              98.500
# 2              98.500
# 3              98.551
# 4              98.556
# ..                ...
# 148           137.700
# 149           137.800
# 150           140.700
# 151           143.400
# 152           146.200
#
# [153 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of GDP column.

# %%
plot_histogram(life_exep_data['GDP'], 'Count', 'GDP', "Histogram of GDP")

# %% [markdown]
# From the above histogram we can conclude that the data has right skewed.

# %%
plot_boxplot('GDP')

# %%
df = get_outlier(life_exep_data, 'GDP')

df[['Country','Year','Gender','GDP']]
# Out:
#                                            Country  Year  Gender  \
# 0                                      Korea, Rep.  2011  Female
# 1                                      Korea, Rep.  2011    Male
# 2     Europe & Central Asia (IDA & IBRD countries)  2003  Female
# 3     Europe & Central Asia (IDA & IBRD countries)  2003    Male
# 4                         Pre-demographic dividend  2017  Female
# ...                                            ...   ...     ...
# 1775                                         World  2017  Female
# 1776                                         World  2018    Male
# 1777                                         World  2018  Female
# 1778                                         World  2019  Female
# 1779                                         World  2019    Male
#
#                     GDP
# 0     1253223044718.990
# 1     1253223044718.990
# 2     1257924182661.530
# 3     1257924182661.530
# 4     1258665620177.510
# ...                 ...
# 1775 81193291658568.797
# 1776 86267600625419.406
# 1777 86267600625419.406
# 1778 87568054407493.094
# 1779 87568054407493.094
#
# [1780 rows x 4 columns]

# %%
# impute_outliers('GDP')

# %%
life_exep_data['GDP'] = np.log(life_exep_data['GDP'])

# %%
plot_histogram(life_exep_data['GDP'], 'Count', 'GDP', "Histogram of GDP")

# %%
plot_boxplot('GDP')

# %% [markdown]
# Next we are going to do visualise the distribution of GNI column.

# %%
plot_histogram(life_exep_data['GNI'], 'Count', 'GNI', "Histogram of GNI")

# %% [markdown]
# From the above histogram we can conclude that the data has right skewed.

# %%
plot_boxplot('GNI')

# %%
df = get_outlier(life_exep_data, 'GNI')

df[['Country','Year','Gender','GNI']]
# Out:
#                                             Country  Year  Gender  \
# 0                                            Canada  2006  Female
# 1                                            Canada  2006    Male
# 2                          Pre-demographic dividend  2018  Female
# 3                          Pre-demographic dividend  2018    Male
# 4     Europe & Central Asia (excluding high income)  2004    Male
# ...                                             ...   ...     ...
# 1809                                          World  2017  Female
# 1810                                          World  2018    Male
# 1811                                          World  2018  Female
# 1812                                          World  2019  Female
# 1813                                          World  2019    Male
#
#                     GNI
# 0     1298296897038.080
# 1     1298296897038.080
# 2     1298903761942.880
# 3     1298903761942.880
# 4     1304878637091.600
# ...                 ...
# 1809 81295071732629.797
# 1810 86243803476022.203
# 1811 86243803476022.203
# 1812 87532722519257.594
# 1813 87532722519257.594
#
# [1814 rows x 4 columns]

# %%
# impute_outliers('GNI')

# %%
life_exep_data['GNI'] = np.log(life_exep_data['GNI'])

# %%
plot_histogram(life_exep_data['GNI'], 'Count', 'GNI', "Histogram of GNI")

# %%
plot_boxplot('GNI')

# %% [markdown]
# Next we are going to do visualise the distribution of Clean fuels and cooking technologies column.

# %%
plot_histogram(life_exep_data['Clean fuels and cooking technologies'], 'Count', 'Clean fuels and cooking technologies', 
               "Histogram of Clean fuels and cooking technologies")

# %% [markdown]
# From the above histogram we can find that most of the data lies between 90 and 100.

# %%
plot_boxplot('Clean fuels and cooking technologies')

# %%
df = get_outlier(life_exep_data, 'Clean fuels and cooking technologies')

df[['Country','Year','Gender','Clean fuels and cooking technologies']]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Gender, Clean fuels and cooking technologies]
# Index: []

# %% [markdown]
# Next we are going to do visualise the distribution of Per Capita column.

# %%
plot_histogram(life_exep_data['Per Capita'], 'Count', 'Per Capita', "Histogram of Per Capita")

# %% [markdown]
# Per Capita income has distribution of right skewed.

# %%
plot_boxplot('Per Capita')

# %%
df = get_outlier(life_exep_data, 'Per Capita')

df[['Country','Year','Gender','Per Capita']]
# Out:
#                         Country  Year  Gender  Per Capita
# 0                     Australia  2005  Female   34081.000
# 1                     Australia  2005    Male   34081.000
# 2     Post-demographic dividend  2005    Male   34154.477
# 3     Post-demographic dividend  2005  Female   34154.477
# 4                  OECD members  2007    Male   34324.687
# ...                         ...   ...     ...         ...
# 1235              Liechtenstein  2019  Female  175813.876
# 1236              Liechtenstein  2014  Female  178864.852
# 1237              Liechtenstein  2014    Male  178864.852
# 1238              Liechtenstein  2018  Female  180366.715
# 1239              Liechtenstein  2018    Male  180366.715
#
# [1240 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of Mortality caused by road traffic injury column.

# %%
plot_histogram(life_exep_data['Mortality caused by road traffic injury'], 'Count', 
               'Mortality caused by road traffic injury', "Histogram of Mortality caused by road traffic injury")

# %% [markdown]
# The above histogram shows that the data are normaly distributed.

# %%
plot_boxplot('Mortality caused by road traffic injury')

# %%
df = get_outlier(life_exep_data, 'Mortality caused by road traffic injury')

df[['Country','Year','Gender','Mortality caused by road traffic injury']]
# Out:
#                Country  Year  Gender  Mortality caused by road traffic injury
# 0         South Africa  2004  Female                                   41.300
# 1         South Africa  2004    Male                                   41.300
# 2              Lesotho  2017  Female                                   42.600
# 3              Lesotho  2017    Male                                   42.600
# 4         South Africa  2003  Female                                   43.400
# 5         South Africa  2003    Male                                   43.400
# 6         South Africa  2000  Female                                   44.000
# 7         South Africa  2000    Male                                   44.000
# 8   Dominican Republic  2017  Female                                   46.300
# 9   Dominican Republic  2017    Male                                   46.300
# 10  Dominican Republic  2018  Female                                   53.500
# 11  Dominican Republic  2018    Male                                   53.500
# 12  Dominican Republic  2019  Female                                   64.600
# 13  Dominican Republic  2019    Male                                   64.600

# %% [markdown]
# Next we are going to do visualise the distribution of Tuberculosis Incidence column.

# %%
plot_histogram(life_exep_data['Tuberculosis Incidence'], 'Count', 'Tuberculosis Incidence', 
               "Histogram of Tuberculosis Incidence")

# %% [markdown]
# Tuberculosis Incidence has distribution of right skewed.

# %%
plot_boxplot('Tuberculosis Incidence')

# %%
df = get_outlier(life_exep_data, 'Tuberculosis Incidence')

df[['Country','Year','Gender','Tuberculosis Incidence']]
# Out:
#            Country  Year  Gender  Tuberculosis Incidence
# 0    Cote d'Ivoire  2000  Female                 367.000
# 1         Djibouti  2015  Female                 367.000
# 2        Indonesia  2002  Female                 367.000
# 3    Cote d'Ivoire  2000    Male                 367.000
# 4         Djibouti  2015    Male                 367.000
# ..             ...   ...     ...                     ...
# 805       Eswatini  2006    Male                1460.000
# 806       Eswatini  2009  Female                1590.000
# 807       Eswatini  2010  Female                1590.000
# 808       Eswatini  2009    Male                1590.000
# 809       Eswatini  2010    Male                1590.000
#
# [810 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of DPT Immunization column.

# %%
plot_histogram(life_exep_data['DPT Immunization'], 'Count', 'DPT Immunization', "Histogram of DPT Immunization")

# %% [markdown]
# The data of DPT Immunization is skewed towards left.

# %%
plot_boxplot('DPT Immunization')

# %%
df = get_outlier(life_exep_data, 'DPT Immunization')

df[['Country','Year','Gender','DPT Immunization']]
# Out:
#          Country  Year  Gender  DPT Immunization
# 0        Ukraine  2016    Male            19.000
# 1           Chad  2008    Male            19.000
# 2           Chad  2008  Female            19.000
# 3        Ukraine  2016  Female            19.000
# 4           Chad  2004  Female            21.000
# ..           ...   ...     ...               ...
# 643     Ethiopia  2009  Female            58.000
# 644        Samoa  2019  Female            58.000
# 645  Afghanistan  2006    Male            58.000
# 646    IDA total  2001    Male            58.182
# 647    IDA total  2001  Female            58.182
#
# [648 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of HepB3 Immunization column.

# %%
plot_histogram(life_exep_data['HepB3 Immunization'], 'Count', 'HepB3 Immunization', "Histogram of HepB3 Immunization")

# %% [markdown]
# The data of HepB3 Immunization is skewed towards left.

# %%
plot_boxplot('HepB3 Immunization')

# %%
df = get_outlier(life_exep_data, 'HepB3 Immunization')

df[['Country','Year','Gender','HepB3 Immunization']]
# Out:
#                      Country  Year  Gender  HepB3 Immunization
# 0                 South Asia  2002    Male               0.050
# 1    South Asia (IDA & IBRD)  2002  Female               0.050
# 2    South Asia (IDA & IBRD)  2002    Male               0.050
# 3                 South Asia  2002  Female               0.050
# 4    South Asia (IDA & IBRD)  2001    Male               0.053
# ..                       ...   ...     ...                 ...
# 645                  Nigeria  2003    Male              45.133
# 646                  Nigeria  2003  Female              45.133
# 647                  Nigeria  2004    Male              45.133
# 648                  Nigeria  2002  Female              45.133
# 649                  Nigeria  2001  Female              45.133
#
# [650 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of Measles Immunization column.

# %%
plot_histogram(life_exep_data['Measles Immunization'], 'Count', 'Measles Immunization', 
               "Histogram of Measles Immunization")

# %% [markdown]
# The data of Measles Immunization is skewed towards left.

# %%
plot_boxplot('Measles Immunization')

# %%
df = get_outlier(life_exep_data, 'Measles Immunization')

df[['Country','Year','Gender','Measles Immunization']]
# Out:
#                                     Country  Year  Gender  \
# 0                                      Chad  2004  Female
# 1                                      Chad  2004    Male
# 2                                   Somalia  2001  Female
# 3                                   Somalia  2001    Male
# 4                                    Angola  2005    Male
# ..                                      ...   ...     ...
# 483                             South Sudan  2006    Male
# 484  Heavily indebted poor countries (HIPC)  2000  Female
# 485  Heavily indebted poor countries (HIPC)  2000    Male
# 486  Heavily indebted poor countries (HIPC)  2001  Female
# 487  Heavily indebted poor countries (HIPC)  2001    Male
#
#      Measles Immunization
# 0                  16.000
# 1                  16.000
# 2                  20.000
# 3                  20.000
# 4                  21.000
# ..                    ...
# 483                54.111
# 484                54.326
# 485                54.326
# 486                54.738
# 487                54.738
#
# [488 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of Hospital beds column.

# %%
plot_histogram(life_exep_data['Hospital beds'], 'Count', 'Unemployment', "Histogram of Hospital beds")

# %% [markdown]
# The data of Hospital beds is skewed towards right.

# %%
plot_boxplot('Hospital beds')

# %%
df = get_outlier(life_exep_data, 'Hospital beds')

df[['Country','Year','Gender','Hospital beds']]
# Out:
#              Country  Year  Gender  Hospital beds
# 0            Estonia  2000    Male          7.040
# 1            Hungary  2013    Male          7.040
# 2    Kyrgyz Republic  2000    Male          7.040
# 3            Hungary  2013  Female          7.040
# 4    Kyrgyz Republic  2000  Female          7.040
# ..               ...   ...     ...            ...
# 603            Japan  2002    Male         14.430
# 604            Japan  2001    Male         14.580
# 605            Japan  2001  Female         14.580
# 606            Japan  2000  Female         14.690
# 607            Japan  2000    Male         14.690
#
# [608 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of Histogram of Basic sanitation services column.

# %%
plot_histogram(life_exep_data['Basic sanitation services'], 'Count', 'Histogram of Basic sanitation services', 
               "Histogram of Basic sanitation services")

# %% [markdown]
# From the above histogram we can find that the most of the data lies between 90 to 100.

# %%
plot_boxplot('Basic sanitation services')

# %%
df = get_outlier(life_exep_data, 'Basic sanitation services')

df[['Country','Year','Gender','Basic sanitation services']]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Gender, Basic sanitation services]
# Index: []

# %% [markdown]
# Next we are going to do visualise the distribution of Tuberculosis treatment column.

# %%
plot_histogram(life_exep_data['Tuberculosis treatment'], 'Count', 'Tuberculosis treatment', 
               "Histogram of Tuberculosis treatment")

# %% [markdown]
# From the above histogram we can find that the most of the data of Tuberculosis treatment lies between 70 to 90.

# %%
plot_boxplot('Tuberculosis treatment')

# %%
df = get_outlier(life_exep_data, 'Tuberculosis treatment')

df[['Country','Year','Gender','Tuberculosis treatment']]
# Out:
#                   Country  Year  Gender  Tuberculosis treatment
# 0                  Greece  2002    Male                   0.000
# 1                  Greece  2005    Male                   0.000
# 2                  Greece  2004    Male                   0.000
# 3              Luxembourg  2017    Male                   0.000
# 4                  Greece  2003    Male                   0.000
# ..                    ...   ...     ...                     ...
# 631               Senegal  2001  Female                  53.000
# 632          South Africa  2010  Female                  53.000
# 633           Congo, Rep.  2006  Female                  53.000
# 634           Congo, Rep.  2006    Male                  53.000
# 635  Syrian Arab Republic  2012  Female                  53.000
#
# [636 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of Urban population column.

# %%
plot_histogram(life_exep_data['Urban population'], 'Count', 'Unemployment', "Histogram of Urban population")

# %% [markdown]
# The above histogram shows that the data has comb distribution.

# %%
plot_boxplot('Urban population')

# %%
df = get_outlier(life_exep_data, 'Urban population')

df[['Country','Year','Gender','Urban population']]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Gender, Urban population]
# Index: []

# %% [markdown]
# Next we are going to do visualise the distribution of Rural population column.

# %%
plot_histogram(life_exep_data['Rural population'], 'Count', 'Rural population', "Histogram of Rural population")

# %% [markdown]
# Distribution of rural population is similar to urban population and has comb distribution.

# %%
plot_boxplot('Rural population')

# %%
df = get_outlier(life_exep_data, 'Rural population')

df[['Country','Year','Gender','Rural population']]
# Out:
# Empty DataFrame
# Columns: [Country, Year, Gender, Rural population]
# Index: []

# %% [markdown]
# Next we are going to do visualise the distribution of Histogram of Non-communicable Mortality column.

# %%
plot_histogram(life_exep_data['Non-communicable Mortality'], 'Count', 'Histogram of Non-communicable Mortality', 
               "Histogram of Non-communicable Mortality")

# %% [markdown]
# Non-communicable data is normally distributed and skewed towards right.

# %%
plot_boxplot('Non-communicable Mortality')

# %%
df = get_outlier(life_exep_data, 'Non-communicable Mortality')

df[['Country','Year','Gender','Non-communicable Mortality']]
# Out:
#              Country  Year  Gender  Non-communicable Mortality
# 0            Lesotho  2016  Female                      41.100
# 1    Solomon Islands  2006    Male                      41.100
# 2    Solomon Islands  2001    Male                      41.100
# 3           Botswana  2007    Male                      41.100
# 4    Solomon Islands  2000    Male                      41.100
# ..               ...   ...     ...                         ...
# 314         Kiribati  2004    Male                      62.600
# 315         Kiribati  2003    Male                      63.000
# 316         Kiribati  2002    Male                      63.600
# 317         Kiribati  2001    Male                      63.900
# 318         Kiribati  2000    Male                      64.100
#
# [319 rows x 4 columns]

# %% [markdown]
# Next we are going to do visualise the distribution of Sucide Rate column.

# %%
plot_histogram(life_exep_data['Sucide Rate'], 'Count', 'Sucide Rate', "Histogram of Sucide Rate")

# %% [markdown]
# Sucide Rate data is kewed towards right.

# %%
plot_boxplot('Sucide Rate')

# %%
df = get_outlier(life_exep_data, 'Sucide Rate')

df[['Country','Year','Gender','Sucide Rate']]
# Out:
#         Country  Year Gender  Sucide Rate
# 0       Austria  2015   Male       24.800
# 1         Japan  2016   Male       24.800
# 2       Austria  2009   Male       24.800
# 3    Cabo Verde  2011   Male       24.800
# 4    Cabo Verde  2012   Male       24.800
# ..          ...   ...    ...          ...
# 747     Lesotho  2017   Male      127.200
# 748     Lesotho  2016   Male      139.600
# 749     Lesotho  2013   Male      139.900
# 750     Lesotho  2015   Male      147.300
# 751     Lesotho  2014   Male      147.800
#
# [752 rows x 4 columns]

# %% [markdown]
# From the above analysis we have found that there is serious issue of outlier on GDP and GNI.

# %%
plt.figure(figsize = (10, 6))
sns.boxplot(data = life_exep_data, x = life_exep_data['Gender'], y = life_exep_data['Life expectancy'], linewidth = 2, 
            palette = "Set1")
plt.xticks(rotation = 45)
plt.savefig(parentDir + "life_expectancy/images/boxplot/" + 'Life expectancy based on Gender.png', transparent=False, facecolor='w')

# %% [markdown]
# From the above boxplot, we can easily pridict that female has higher Life expectancy than male.

# %%
def plot_regplot(column):
    # The seaborn.set() function is used to control the theme and configurations of the seaborn plot.
    # The rc parameter of the function can be used to control the size of the final figure.
    # We will pass a dictionary as the value to this parameter with the key as figure.figsize and the required dimensions as the value.
    sns.set(rc = {'figure.figsize':(10,10)})
    sns.regplot(y = "Life expectancy", x = column, data = life_exep_data, scatter_kws={'s' : 1}, 
            line_kws = {"color" : "red"})
    plt.savefig(parentDir + "life_expectancy/images/regplot/" + column +'.png', transparent=False, facecolor='w')

# %%
plot_regplot('Unemployment')

# %%
plot_regplot('Infant Mortality')

# %%
plot_regplot('GDP')

# %%
plot_regplot('GNI')

# %%
plot_regplot('Clean fuels and cooking technologies')

# %%
plot_regplot('Per Capita')

# %%
plot_regplot('Mortality caused by road traffic injury')

# %%
plot_regplot('Tuberculosis Incidence')

# %%
plot_regplot('DPT Immunization')

# %%
plot_regplot('HepB3 Immunization')

# %%
plot_regplot('Measles Immunization')

# %%
plot_regplot('Hospital beds')

# %%
plot_regplot('Basic sanitation services')

# %%
plot_regplot('Tuberculosis treatment')

# %%
plot_regplot('Urban population')

# %%
plot_regplot('Rural population')

# %%
plot_regplot('Non-communicable Mortality')

# %%
plot_regplot('Sucide Rate')

# %%
life_exep_data.corr()
# Out:
#                                           Year  Life expectancy  Unemployment  \
# Year                                     1.000            0.207        -0.041
# Life expectancy                          0.207            1.000         0.030
# Unemployment                            -0.041            0.030         1.000
# Infant Mortality                        -0.210           -0.875        -0.088
# GDP                                      0.144            0.297        -0.158
# GNI                                      0.143            0.312        -0.152
# Clean fuels and cooking technologies     0.072            0.752         0.157
# Per Capita                               0.137            0.558        -0.090
# Mortality caused by road traffic injury -0.105           -0.649        -0.003
# Tuberculosis Incidence                  -0.079           -0.607         0.158
# DPT Immunization                         0.144            0.622         0.076
# HepB3 Immunization                       0.253            0.402         0.074
# Measles Immunization                     0.147            0.625         0.052
# Hospital beds                           -0.035            0.400         0.045
# Basic sanitation services                0.114            0.831         0.139
# Tuberculosis treatment                   0.075           -0.063        -0.114
# Urban population                         0.085            0.613         0.120
# Rural population                        -0.085           -0.613        -0.120
# Non-communicable Mortality              -0.156           -0.613         0.048
# Sucide Rate                             -0.056           -0.159         0.073
#
#                                          Infant Mortality    GDP    GNI  \
# Year                                               -0.210  0.144  0.143
# Life expectancy                                    -0.875  0.297  0.312
# Unemployment                                       -0.088 -0.158 -0.152
# Infant Mortality                                    1.000 -0.263 -0.264
# GDP                                                -0.263  1.000  0.980
# GNI                                                -0.264  0.980  1.000
# Clean fuels and cooking technologies               -0.806  0.332  0.330
# Per Capita                                         -0.414  0.192  0.206
# Mortality caused by road traffic injury             0.620 -0.172 -0.175
# Tuberculosis Incidence                              0.509 -0.149 -0.148
# DPT Immunization                                   -0.753  0.127  0.128
# HepB3 Immunization                                 -0.530 -0.108 -0.106
# Measles Immunization                               -0.752  0.155  0.156
# Hospital beds                                      -0.489  0.210  0.212
# Basic sanitation services                          -0.841  0.241  0.252
# Tuberculosis treatment                              0.053 -0.016 -0.005
# Urban population                                   -0.582  0.324  0.350
# Rural population                                    0.582 -0.324 -0.350
# Non-communicable Mortality                          0.444 -0.354 -0.349
# Sucide Rate                                        -0.046  0.007  0.008
#
#                                          Clean fuels and cooking technologies  \
# Year                                                                    0.072
# Life expectancy                                                         0.752
# Unemployment                                                            0.157
# Infant Mortality                                                       -0.806
# GDP                                                                     0.332
# GNI                                                                     0.330
# Clean fuels and cooking technologies                                    1.000
# Per Capita                                                              0.441
# Mortality caused by road traffic injury                                -0.555
# Tuberculosis Incidence                                                 -0.506
# DPT Immunization                                                        0.609
# HepB3 Immunization                                                      0.400
# Measles Immunization                                                    0.636
# Hospital beds                                                           0.467
# Basic sanitation services                                               0.867
# Tuberculosis treatment                                                 -0.166
# Urban population                                                        0.686
# Rural population                                                       -0.686
# Non-communicable Mortality                                             -0.433
# Sucide Rate                                                             0.092
#
#                                          Per Capita  \
# Year                                          0.137
# Life expectancy                               0.558
# Unemployment                                 -0.090
# Infant Mortality                             -0.414
# GDP                                           0.192
# GNI                                           0.206
# Clean fuels and cooking technologies          0.441
# Per Capita                                    1.000
# Mortality caused by road traffic injury      -0.427
# Tuberculosis Incidence                       -0.288
# DPT Immunization                              0.278
# HepB3 Immunization                            0.135
# Measles Immunization                          0.262
# Hospital beds                                 0.272
# Basic sanitation services                     0.506
# Tuberculosis treatment                       -0.243
# Urban population                              0.489
# Rural population                             -0.489
# Non-communicable Mortality                   -0.380
# Sucide Rate                                   0.058
#
#                                          Mortality caused by road traffic injury  \
# Year                                                                      -0.105
# Life expectancy                                                           -0.649
# Unemployment                                                              -0.003
# Infant Mortality                                                           0.620
# GDP                                                                       -0.172
# GNI                                                                       -0.175
# Clean fuels and cooking technologies                                      -0.555
# Per Capita                                                                -0.427
# Mortality caused by road traffic injury                                    1.000
# Tuberculosis Incidence                                                     0.414
# DPT Immunization                                                          -0.393
# HepB3 Immunization                                                        -0.204
# Measles Immunization                                                      -0.380
# Hospital beds                                                             -0.413
# Basic sanitation services                                                 -0.605
# Tuberculosis treatment                                                     0.079
# Urban population                                                          -0.378
# Rural population                                                           0.378
# Non-communicable Mortality                                                 0.297
# Sucide Rate                                                               -0.040
#
#                                          Tuberculosis Incidence  \
# Year                                                     -0.079
# Life expectancy                                          -0.607
# Unemployment                                              0.158
# Infant Mortality                                          0.509
# GDP                                                      -0.149
# GNI                                                      -0.148
# Clean fuels and cooking technologies                     -0.506
# Per Capita                                               -0.288
# Mortality caused by road traffic injury                   0.414
# Tuberculosis Incidence                                    1.000
# DPT Immunization                                         -0.343
# HepB3 Immunization                                       -0.207
# Measles Immunization                                     -0.344
# Hospital beds                                            -0.189
# Basic sanitation services                                -0.531
# Tuberculosis treatment                                    0.029
# Urban population                                         -0.384
# Rural population                                          0.384
# Non-communicable Mortality                                0.415
# Sucide Rate                                               0.175
#
#                                          DPT Immunization  HepB3 Immunization  \
# Year                                                0.144               0.253
# Life expectancy                                     0.622               0.402
# Unemployment                                        0.076               0.074
# Infant Mortality                                   -0.753              -0.530
# GDP                                                 0.127              -0.108
# GNI                                                 0.128              -0.106
# Clean fuels and cooking technologies                0.609               0.400
# Per Capita                                          0.278               0.135
# Mortality caused by road traffic injury            -0.393              -0.204
# Tuberculosis Incidence                             -0.343              -0.207
# DPT Immunization                                    1.000               0.715
# HepB3 Immunization                                  0.715               1.000
# Measles Immunization                                0.929               0.691
# Hospital beds                                       0.350               0.196
# Basic sanitation services                           0.643               0.443
# Tuberculosis treatment                              0.006               0.051
# Urban population                                    0.400               0.264
# Rural population                                   -0.400              -0.264
# Non-communicable Mortality                         -0.269              -0.147
# Sucide Rate                                         0.110               0.032
#
#                                          Measles Immunization  Hospital beds  \
# Year                                                    0.147         -0.035
# Life expectancy                                         0.625          0.400
# Unemployment                                            0.052          0.045
# Infant Mortality                                       -0.752         -0.489
# GDP                                                     0.155          0.210
# GNI                                                     0.156          0.212
# Clean fuels and cooking technologies                    0.636          0.467
# Per Capita                                              0.262          0.272
# Mortality caused by road traffic injury                -0.380         -0.413
# Tuberculosis Incidence                                 -0.344         -0.189
# DPT Immunization                                        0.929          0.350
# HepB3 Immunization                                      0.691          0.196
# Measles Immunization                                    1.000          0.373
# Hospital beds                                           0.373          1.000
# Basic sanitation services                               0.665          0.500
# Tuberculosis treatment                                  0.021         -0.144
# Urban population                                        0.414          0.344
# Rural population                                       -0.414         -0.344
# Non-communicable Mortality                             -0.269         -0.097
# Sucide Rate                                             0.113          0.328
#
#                                          Basic sanitation services  \
# Year                                                         0.114
# Life expectancy                                              0.831
# Unemployment                                                 0.139
# Infant Mortality                                            -0.841
# GDP                                                          0.241
# GNI                                                          0.252
# Clean fuels and cooking technologies                         0.867
# Per Capita                                                   0.506
# Mortality caused by road traffic injury                     -0.605
# Tuberculosis Incidence                                      -0.531
# DPT Immunization                                             0.643
# HepB3 Immunization                                           0.443
# Measles Immunization                                         0.665
# Hospital beds                                                0.500
# Basic sanitation services                                    1.000
# Tuberculosis treatment                                      -0.107
# Urban population                                             0.659
# Rural population                                            -0.659
# Non-communicable Mortality                                  -0.370
# Sucide Rate                                                  0.094
#
#                                          Tuberculosis treatment  \
# Year                                                      0.075
# Life expectancy                                          -0.063
# Unemployment                                             -0.114
# Infant Mortality                                          0.053
# GDP                                                      -0.016
# GNI                                                      -0.005
# Clean fuels and cooking technologies                     -0.166
# Per Capita                                               -0.243
# Mortality caused by road traffic injury                   0.079
# Tuberculosis Incidence                                    0.029
# DPT Immunization                                          0.006
# HepB3 Immunization                                        0.051
# Measles Immunization                                      0.021
# Hospital beds                                            -0.144
# Basic sanitation services                                -0.107
# Tuberculosis treatment                                    1.000
# Urban population                                         -0.193
# Rural population                                          0.193
# Non-communicable Mortality                                0.119
# Sucide Rate                                              -0.077
#
#                                          Urban population  Rural population  \
# Year                                                0.085            -0.085
# Life expectancy                                     0.613            -0.613
# Unemployment                                        0.120            -0.120
# Infant Mortality                                   -0.582             0.582
# GDP                                                 0.324            -0.324
# GNI                                                 0.350            -0.350
# Clean fuels and cooking technologies                0.686            -0.686
# Per Capita                                          0.489            -0.489
# Mortality caused by road traffic injury            -0.378             0.378
# Tuberculosis Incidence                             -0.384             0.384
# DPT Immunization                                    0.400            -0.400
# HepB3 Immunization                                  0.264            -0.264
# Measles Immunization                                0.414            -0.414
# Hospital beds                                       0.344            -0.344
# Basic sanitation services                           0.659            -0.659
# Tuberculosis treatment                             -0.193             0.193
# Urban population                                    1.000            -1.000
# Rural population                                   -1.000             1.000
# Non-communicable Mortality                         -0.432             0.432
# Sucide Rate                                         0.046            -0.046
#
#                                          Non-communicable Mortality  \
# Year                                                         -0.156
# Life expectancy                                              -0.613
# Unemployment                                                  0.048
# Infant Mortality                                              0.444
# GDP                                                          -0.354
# GNI                                                          -0.349
# Clean fuels and cooking technologies                         -0.433
# Per Capita                                                   -0.380
# Mortality caused by road traffic injury                       0.297
# Tuberculosis Incidence                                        0.415
# DPT Immunization                                             -0.269
# HepB3 Immunization                                           -0.147
# Measles Immunization                                         -0.269
# Hospital beds                                                -0.097
# Basic sanitation services                                    -0.370
# Tuberculosis treatment                                        0.119
# Urban population                                             -0.432
# Rural population                                              0.432
# Non-communicable Mortality                                    1.000
# Sucide Rate                                                   0.501
#
#                                          Sucide Rate
# Year                                          -0.056
# Life expectancy                               -0.159
# Unemployment                                   0.073
# Infant Mortality                              -0.046
# GDP                                            0.007
# GNI                                            0.008
# Clean fuels and cooking technologies           0.092
# Per Capita                                     0.058
# Mortality caused by road traffic injury       -0.040
# Tuberculosis Incidence                         0.175
# DPT Immunization                               0.110
# HepB3 Immunization                             0.032
# Measles Immunization                           0.113
# Hospital beds                                  0.328
# Basic sanitation services                      0.094
# Tuberculosis treatment                        -0.077
# Urban population                               0.046
# Rural population                              -0.046
# Non-communicable Mortality                     0.501
# Sucide Rate                                    1.000

# %%
plt.figure(figsize = (15, 15))
sns.heatmap(life_exep_data.corr(), annot = True, fmt = ".2f")
# Out:
# <AxesSubplot:>

# %% [markdown]
# From the above corelation plot we can easily say that there are some multicollinearity issues between the variables. To solve this issue we are going to implement the PCA technique (feature selection).

# %% [markdown]
# ## Standarize the data
# We going to encode the Gender column because based on our research question we are going to predict the life expectancy base on the development indicators.

# %%
X = life_exep_data.drop(['Country', 'Year', 'Life expectancy', 'Gender'], axis = 1)
Y = life_exep_data['Life expectancy']

# %%
X.shape, Y.shape
# Out:
# ((9928, 18), (9928,))

# %%
X
# Out:
#       Unemployment  Infant Mortality    GDP    GNI  \
# 0           13.846            85.000 23.340 23.627
# 1           13.849            82.700 23.340 23.627
# 2           14.355            80.400 22.123 23.627
# 3           14.222            77.800 22.231 23.627
# 4           14.047            75.300 22.377 23.627
# ...            ...               ...    ...    ...
# 9923         4.352            46.600 23.717 23.699
# 9924         4.358            45.100 23.746 23.727
# 9925         4.353            44.200 23.590 23.573
# 9926         4.360            42.900 23.620 23.603
# 9927         4.393            42.100 23.683 23.662
#
#       Clean fuels and cooking technologies  Per Capita  \
# 0                                    6.400     434.740
# 1                                    7.200     434.740
# 2                                    8.200     179.427
# 3                                    9.400     190.684
# 4                                   10.400     211.382
# ...                                    ...         ...
# 9923                                29.800    1445.070
# 9924                                29.700    1464.589
# 9925                                29.600    1235.189
# 9926                                29.800    1254.642
# 9927                                30.000    1316.741
#
#       Mortality caused by road traffic injury  Tuberculosis Incidence  \
# 0                                      14.700                 190.000
# 1                                      15.100                 189.000
# 2                                      14.900                 189.000
# 3                                      15.000                 189.000
# 4                                      15.200                 189.000
# ...                                       ...                     ...
# 9923                                   38.700                 242.000
# 9924                                   39.900                 233.000
# 9925                                   40.100                 221.000
# 9926                                   40.600                 210.000
# 9927                                   41.200                 199.000
#
#       DPT Immunization  HepB3 Immunization  Measles Immunization  \
# 0               24.000              65.077                27.000
# 1               33.000              65.077                37.000
# 2               36.000              65.077                35.000
# 3               41.000              65.077                39.000
# 4               50.000              65.077                48.000
# ...                ...                 ...                   ...
# 9923            87.000              87.000                86.000
# 9924            90.000              90.000                95.000
# 9925            89.000              89.000                90.000
# 9926            89.000              89.000                88.000
# 9927            90.000              90.000                85.000
#
#       Hospital beds  Basic sanitation services  Tuberculosis treatment  \
# 0             0.300                     21.871                  85.000
# 1             0.390                     21.881                  84.000
# 2             0.390                     23.274                  87.000
# 3             0.390                     24.667                  86.000
# 4             0.390                     26.068                  89.000
# ...             ...                        ...                     ...
# 9923          2.350                     38.121                  81.000
# 9924          2.350                     37.529                  81.000
# 9925          2.350                     36.942                  83.000
# 9926          2.350                     36.357                  84.000
# 9927          2.350                     35.774                  84.000
#
#       Urban population  Rural population  Non-communicable Mortality  \
# 0               22.078            77.922                      39.400
# 1               22.169            77.831                      40.100
# 2               22.261            77.739                      40.500
# 3               22.353            77.647                      40.100
# 4               22.500            77.500                      40.200
# ...                ...               ...                         ...
# 9923            32.385            67.615                      32.500
# 9924            32.296            67.704                      31.800
# 9925            32.237            67.763                      30.900
# 9926            32.209            67.791                      30.300
# 9927            32.210            67.790                      30.300
#
#       Sucide Rate
# 0           4.800
# 1           4.800
# 2           4.600
# 3           4.600
# 4           4.600
# ...           ...
# 9923       23.800
# 9924       22.500
# 9925       21.000
# 9926       19.900
# 9927       20.000
#
# [9928 rows x 18 columns]

# %%
Y
# Out:
# 0      57.120
# 1      57.596
# 2      58.080
# 3      58.578
# 4      59.093
#         ...
# 9923   57.778
# 9924   58.565
# 9925   59.105
# 9926   59.501
# 9927   59.798
# Name: Life expectancy, Length: 9928, dtype: float64

# %%
# Splitting the X and Y into the Training set and Testing set
X_train, X_test, Y_train, Y_test = train_test_split(X, Y, test_size = 0.2, random_state = 7)

# %%
X_train.shape, X_test.shape, Y_train.shape, Y_test.shape
# Out:
# ((7942, 18), (1986, 18), (7942,), (1986,))

# %%
# Doing the pre-processing part on training and testing set such as fitting the Standard scale.
scaler = StandardScaler()
  
transformed_X_train = scaler.fit_transform(X_train)
transformed_X_test = scaler.transform(X_test)

# %%
# Applying PCA function on training
# and testing set of X component
pca = PCA(n_components = 0.9)
  
pca_data = pca.fit(transformed_X_train)

# %%
pca_data.explained_variance_ratio_
# Out:
# array([0.39101889, 0.12669721, 0.09031476, 0.08083984, 0.06225106,
#        0.04719767, 0.04592309, 0.03526085, 0.03067709])

# %% [markdown]
# From the 90% threshold our 18 attributes has been reduced to 9 attributes. This will help use to improve the performance of algorithm significantly.
#
# Lets convert the variance ratio to percentage so that it will be easy to under stand the variance of each component.

# %%
np.cumsum(np.round(pca_data.explained_variance_ratio_, decimals = 4) * 100)
# Out:
# array([39.1 , 51.77, 60.8 , 68.88, 75.11, 79.83, 84.42, 87.95, 91.02])

# %%
loadings = pca_data.components_
labels = []
for x in range(1, len(pca_data.components_) + 1):
    labels.append('PC' + str(x))

d1 = dict(zip(labels, loadings))
# construct dataframe from dict of array-lik
loadings_df = pd.DataFrame.from_dict(d1)
# created new column name as 'variable' having values from all column names of X_train
loadings_df['variable'] = X_train.columns.values
# seting 'vaiable' column as index  column
loadings_df = loadings_df.set_index('variable')
loadings_df
# Out:
#                                            PC1    PC2    PC3    PC4    PC5  \
# variable
# Unemployment                            -0.025  0.202  0.203  0.301  0.589
# Infant Mortality                         0.339 -0.110  0.058  0.069  0.036
# GDP                                     -0.151 -0.484  0.144 -0.373  0.162
# GNI                                     -0.154 -0.484  0.149 -0.367  0.169
# Clean fuels and cooking technologies    -0.337  0.014  0.054  0.057  0.041
# Per Capita                              -0.215 -0.120  0.051  0.254 -0.295
# Mortality caused by road traffic injury  0.242 -0.010  0.003 -0.070  0.393
# Tuberculosis Incidence                   0.214  0.067  0.306 -0.066  0.322
# DPT Immunization                        -0.282  0.288 -0.091 -0.245  0.111
# HepB3 Immunization                      -0.194  0.381 -0.180 -0.172  0.169
# Measles Immunization                    -0.286  0.269 -0.078 -0.266  0.108
# Hospital beds                           -0.204  0.055  0.347 -0.073 -0.258
# Basic sanitation services               -0.340  0.078  0.032  0.053 -0.063
# Tuberculosis treatment                   0.058  0.070 -0.241 -0.462  0.028
# Urban population                        -0.294 -0.129  0.106  0.245  0.205
# Rural population                         0.294  0.129 -0.106 -0.245 -0.205
# Non-communicable Mortality               0.201  0.273  0.396 -0.154 -0.118
# Sucide Rate                             -0.018  0.192  0.639 -0.166 -0.166
#
#                                            PC6    PC7    PC8    PC9
# variable
# Unemployment                            -0.425  0.312  0.129 -0.171
# Infant Mortality                         0.110 -0.116 -0.003  0.023
# GDP                                      0.036  0.140 -0.007 -0.114
# GNI                                      0.029  0.109  0.008 -0.108
# Clean fuels and cooking technologies    -0.136  0.044 -0.123 -0.121
# Per Capita                               0.287 -0.126  0.627 -0.185
# Mortality caused by road traffic injury  0.346 -0.242 -0.273  0.168
# Tuberculosis Incidence                   0.185  0.074  0.582  0.253
# DPT Immunization                         0.211  0.089  0.034 -0.079
# HepB3 Immunization                       0.305 -0.054  0.040  0.100
# Measles Immunization                     0.191  0.067 -0.005 -0.044
# Hospital beds                           -0.141  0.220 -0.062  0.776
# Basic sanitation services               -0.166  0.002 -0.021 -0.114
# Tuberculosis treatment                  -0.564 -0.485  0.339  0.101
# Urban population                         0.013 -0.445 -0.077  0.134
# Rural population                        -0.013  0.445  0.077 -0.134
# Non-communicable Mortality              -0.079 -0.209 -0.154 -0.246
# Sucide Rate                              0.065 -0.193 -0.059 -0.253

# %%
pca_df = pd.DataFrame({'Explained variance':pca_data.explained_variance_ratio_, 'Components':labels})
plt.figure(figsize=(15, 15))
sns.barplot(x = 'Components', y = "Explained variance", data = pca_df, color = "c").set_title("PCA: variance plot")
# Out:
# Text(0.5, 1.0, 'PCA: variance plot')

# %%
plt.plot(np.cumsum(pca_data.explained_variance_ratio_))
plt.xlabel("Number of components")
plt.ylabel("Explained variance")
# Out:
# Text(0, 0.5, 'Explained variance')

# %%
X_train_pca = pca.transform(transformed_X_train)
X_test_pca = pca.transform(transformed_X_test)

# %%
X_train_pca.shape, X_test_pca.shape, Y_train.shape, Y_test.shape
# Out:
# ((7942, 9), (1986, 9), (7942,), (1986,))

# %%
pd.DataFrame(X_train_pca).to_csv(parentDir + 'life_expectancy/imp/X_train.csv', index = False)
pd.DataFrame(X_test_pca).to_csv(parentDir + 'life_expectancy/imp/X_test.csv', index = False)
Y_train.to_csv(parentDir +  'life_expectancy/imp/Y_train.csv', index=False)
Y_test.to_csv(parentDir +  'life_expectancy/imp/Y_test.csv', index=False)
